# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import scipy.stats 

from utils import *

# %% [markdown]
# ## Visualisation de la fonction de densité de Gumbel

# %%
x = np.linspace(-5, 10, num=1000)

fig, ax = plt.subplots()
ax.plot(x, scipy.stats.gumbel_r.pdf(x), label="Gumbel (0, 1)")
ax.plot(x, scipy.stats.gumbel_r.pdf(x, loc=5, scale=2), label="Gumbel (5, 5)")
plt.grid()
plt.legend()

# %% [markdown]
# ## Convergence des estimateurs

# %%
test_alpha_convergence(10, "moments", N=10000)

# %%
test_m_convergence(5, "moments", N=10000)

# %%
test_alpha_convergence(1, "likelihood", N=10000)

# %%
test_m_convergence(5, "likelihood", N=10000)

# %%
test_m_convergence(5, "both", N=10000)

# %%
test_alpha_convergence(10, "both", N=10000)
